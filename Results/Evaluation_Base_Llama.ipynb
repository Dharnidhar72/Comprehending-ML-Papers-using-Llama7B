# %%
# !pip install ragas
# Out:
# Collecting ragas
#   Downloading ragas-0.1.7-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 kB 755.9 kB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ragas) (1.25.2)
# Collecting datasets (from ragas)
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 11.3 MB/s eta 0:00:00
# Collecting tiktoken (from ragas)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 29.7 MB/s eta 0:00:00
# Collecting langchain (from ragas)
#   Downloading langchain-0.1.15-py3-none-any.whl (814 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 814.5/814.5 kB 25.6 MB/s eta 0:00:00
# Collecting langchain-core (from ragas)
#   Downloading langchain_core-0.1.41-py3-none-any.whl (278 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.4/278.4 kB 22.6 MB/s eta 0:00:00
# Collecting langchain-community (from ragas)
#   Downloading langchain_community-0.0.32-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 37.3 MB/s eta 0:00:00
# Collecting langchain-openai (from ragas)
#   Downloading langchain_openai-0.1.2-py3-none-any.whl (33 kB)
# Collecting openai>1 (from ragas)
#   Downloading openai-1.17.0-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.3/268.3 kB 28.7 MB/s eta 0:00:00
# Collecting pysbd>=0.3.4 (from ragas)
#   Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ragas) (1.6.0)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from ragas) (1.4.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>1->ragas) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>1->ragas) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai>1->ragas)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai>1->ragas) (2.6.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>1->ragas) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai>1->ragas) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai>1->ragas) (4.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (3.13.3)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->ragas)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (2.31.0)
# Collecting xxhash (from datasets->ragas)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 6.2 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->ragas)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets->ragas) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain->ragas) (2.0.29)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain->ragas) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain->ragas)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain->ragas)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain->ragas)
#   Downloading langchain_text_splitters-0.0.1-py3-none-any.whl (21 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain->ragas)
#   Downloading langsmith-0.1.45-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.2/104.2 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain->ragas) (8.2.3)
# Collecting packaging (from datasets->ragas)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->ragas) (2023.12.25)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->ragas) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>1->ragas) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>1->ragas) (1.2.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain->ragas)
#   Downloading marshmallow-3.21.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.7 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain->ragas)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>1->ragas) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>1->ragas)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.1 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai>1->ragas)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.0 MB/s eta 0:00:00
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain->ragas)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain->ragas)
#   Downloading orjson-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>1->ragas) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai>1->ragas) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->ragas) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->ragas) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain->ragas) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->ragas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->ragas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->ragas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->ragas) (1.16.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain->ragas)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: xxhash, pysbd, packaging, orjson, mypy-extensions, jsonpointer, h11, dill, typing-inspect, tiktoken, multiprocess, marshmallow, jsonpatch, httpcore, langsmith, httpx, dataclasses-json, openai, langchain-core, datasets, langchain-text-splitters, langchain-openai, langchain-community, langchain, ragas
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed dataclasses-json-0.6.4 datasets-2.18.0 dill-0.3.8 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 jsonpatch-1.33 jsonpointer-2.4 langchain-0.1.15 langchain-community-0.0.32 langchain-core-0.1.41 langchain-openai-0.1.2 langchain-text-splitters-0.0.1 langsmith-0.1.45 marshmallow-3.21.1 multiprocess-0.70.16 mypy-extensions-1.0.0 openai-1.17.0 orjson-3.10.0 packaging-23.2 pysbd-0.3.4 ragas-0.1.7 tiktoken-0.6.0 typing-inspect-0.9.0 xxhash-3.4.1

# %%
import pandas as pd

# %%
import os
os.environ["OPENAI_API_KEY"] = "use_your_key"

# %%
df = pd.read_excel("/content/QA.xlsx")

# %%
from ragas.metrics import (
    context_relevancy,
    answer_relevancy,
    faithfulness,
    context_recall,
)
from ragas.metrics.critique import harmfulness
from ragas import evaluate

# %%
df.columns
# Out:
# Index(['Paper', 'Question', 'Original_answer', 'Model_Answer', 'Context'], dtype='object')

# %%
df
# Out:
#    Paper                                           Question  \
# 0    NaN  What is the purpose of the Exempt Officers' an...
# 1    NaN  What are some essential job duties of a police...
# 2    NaN  What is the purpose of the MOU signed between ...
# 3    NaN  Why does the San Jose Police Department have a...
# 4    NaN  What is the purpose of the MOU signed between ...
# 5    NaN           Who are the parties involved in the MOU?
# 6    NaN  What is the purpose of the Exempt Officers’ an...
# 7    NaN  Who is eligible for the Exempt Officers’ and S...
# 8    NaN  What is the grievance process for claims regar...
# 9    NaN  How does the Program affect the transfer polic...
#
#                                      Original_answer  \
# 0  The purpose of the Exempt Officers' and Sergea...
# 1  Some essential job duties of a police officer ...
# 2  The purpose of the MOU is to establish an agre...
# 3  The San Jose Police Department has a legitimat...
# 4  The purpose of the MOU is to establish the pol...
# 5  The parties involved in the MOU are the City o...
# 6  The purpose of the Program is to provide a tem...
# 7  Officers and sergeants with temporary work res...
# 8  Claims regarding the interpretation and applic...
# 9  Nothing in the Program affects the provisions ...
#
#                                         Model_Answer  \
# 0  The Exempt Officers' and Sergeants' Modified D...
# 1  Key responsibilities of a police officer and s...
# 2  The MOU aims to formalize an understanding bet...
# 3  The San Jose Police Department is rightfully f...
# 4  The MOU is designed to set forth the guideline...
# 5  The MOU is a collaborative agreement between t...
# 6  The aim of the Program is to offer a provision...
# 7  The Program is open to officers and sergeants ...
# 8  Issues related to how the Program's specific t...
# 9  The Program does not impact the existing condi...
#
#                                              Context
# 0  Understanding the accommodations and support p...
# 1   Insight into the daily responsibilities and e...
# 2   Clarification of the objectives behind the ag...
# 3  The operational philosophy of the San Jose Pol...
# 4  The objectives behind forming agreements (MOU)...
# 5   Identification of stakeholders involved in th...
# 6  The reasoning and goals for establishing a pro...
# 7  Eligibility criteria for the Modified Duty Pro...
# 8  Procedures and protocols in place within the S...
# 9  The relationship between the Modified Duty Pro...

# %%
# Define a dictionary with current column names as keys and new names as values
column_name_mapping = {
    'Question': 'question',
    'Original_answer': 'ground_truths',
    'Model_Answer': 'answer',
    'Context': 'contexts',
    # Add more as needed
}
# Use the rename method to change column names
df.rename(columns=column_name_mapping, inplace=True)
# Print the DataFrame to verify the changes
print(df)
# Out:
#                                             question  \
# 0  What is the purpose of the Exempt Officers' an...
# 1  What are some essential job duties of a police...
# 2  What is the purpose of the MOU signed between ...
# 3  Why does the San Jose Police Department have a...
# 4  What is the purpose of the MOU signed between ...
# 5           Who are the parties involved in the MOU?
# 6  What is the purpose of the Exempt Officers’ an...
# 7  Who is eligible for the Exempt Officers’ and S...
# 8  What is the grievance process for claims regar...
# 9  How does the Program affect the transfer polic...
#
#                                        ground_truths  \
# 0  The purpose of the Exempt Officers' and Sergea...
# 1  Some essential job duties of a police officer ...
# 2  The purpose of the MOU is to establish an agre...
# 3  The San Jose Police Department has a legitimat...
# 4  The purpose of the MOU is to establish the pol...
# 5  The parties involved in the MOU are the City o...
# 6  The purpose of the Program is to provide a tem...
# 7  Officers and sergeants with temporary work res...
# 8  Claims regarding the interpretation and applic...
# 9  Nothing in the Program affects the provisions ...
#
#                                               answer  \
# 0  The Exempt Officers' and Sergeants' Modified D...
# 1  Key responsibilities of a police officer and s...
# 2  The MOU aims to formalize an understanding bet...
# 3  The San Jose Police Department is rightfully f...
# 4  The MOU is designed to set forth the guideline...
# 5  The MOU is a collaborative agreement between t...
# 6  The aim of the Program is to offer a provision...
# 7  The Program is open to officers and sergeants ...
# 8  Issues related to how the Program's specific t...
# 9  The Program does not impact the existing condi...
#
#                                             contexts
# 0  [Understanding the accommodations and support ...
# 1  [ Insight into the daily responsibilities and ...
# 2  [ Clarification of the objectives behind the a...
# 3  [The operational philosophy of the San Jose Po...
# 4  [The objectives behind forming agreements (MOU...
# 5  [ Identification of stakeholders involved in t...
# 6  [The reasoning and goals for establishing a pr...
# 7  [Eligibility criteria for the Modified Duty Pr...
# 8  [Procedures and protocols in place within the ...
# 9  [The relationship between the Modified Duty Pr...

# %%
# # Replace 'column_to_drop' with the actual name of the column you want to drop
column_to_drop = 'Paper'
# # Use the drop method to remove the specified column
df.drop(column_to_drop, axis=1, inplace=True)
# # Print the DataFrame to verify the changes
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-aff4fde1c88d> in <cell line: 4>()
#       2 column_to_drop = 'Paper'
#       3 # # Use the drop method to remove the specified column
# ----> 4 df.drop(column_to_drop, axis=1, inplace=True)
#       5 # # Print the DataFrame to verify the changes
#       6 print(df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4589                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4590             else:
# -> 4591                 new_axis = axis.drop(labels, errors=errors)
#    4592             indexer = axis.get_indexer(new_axis)
#    4593
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6697         if mask.any():
#    6698             if errors != "ignore":
# -> 6699                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700             indexer = indexer[~mask]
#    6701         return self.delete(indexer)
#
# KeyError: "['Paper'] not found in axis"

# %%
from datasets import Dataset
# Assuming df is your DataFrame
df['contexts'] = df['contexts'].apply(lambda x: [str(x)]).tolist()
df['ground_truths'] = df['ground_truths'].apply(lambda x: [str(x)]).tolist()
data_dict = {
    'question': df['question'].tolist(),
    'ground_truths': df['ground_truths'].tolist(),
    'answer': df['answer'].tolist(),
    'contexts': df['contexts'],
}
# Convert the 'contexts' column to a list of strings
custom_dataset = Dataset.from_dict(data_dict)

# Now, you can use custom_dataset in the evaluate function
result = evaluate(
    custom_dataset,
    metrics=[
        context_relevancy,
        faithfulness,
        answer_relevancy,
        context_recall,
        harmfulness,
    ],
)
result
# Out:
# WARNING:ragas.validation:passing column names as 'ground_truths' is deprecated and will be removed in the next version, please use 'ground_truth' instead. Note that `ground_truth` should be of type string and not Sequence[string] like `ground_truths`
# Evaluating:   0%|          | 0/50 [00:00<?, ?it/s]
# {'context_relevancy': 0.3000, 'faithfulness': 0.8750, 'answer_relevancy': 0.9069, 'context_recall': 0.9000, 'harmfulness': 0.0000}
